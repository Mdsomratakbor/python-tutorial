# %% [markdown]
# 🧩 What Is Pandas?
#
# Pandas is a Python library used for data manipulation and analysis. It provides two main data structures:
#
# Series – a one-dimensional labeled array (like a column in Excel)
#
# DataFrame – a two-dimensional labeled data table (like an Excel sheet)
#
# You’ll typically use Pandas to:
#
# Load data (from CSV, Excel, SQL, etc.)
#
# Clean and transform data
#
# Analyze and summarize data

# %%
import pandas as pd

# %%
# Create a simple dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
    'Age': [25, 30, 35, 40, 22],
    'City': ['New York', 'Paris', 'London', 'Berlin', 'Tokyo']
}

# Convert dictionary to a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London
# 3    David   40    Berlin
# 4     Emma   22     Tokyo

# %%
# Read from a CSV file
df = pd.read_csv('G:/PythonLearningCourse/Pandas/data/data.csv')

# Write to a CSV file
df.to_csv('output.csv', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\User\AppData\Local\Temp\ipykernel_25912\1375733126.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('G:\PythonLearningCourse\Pandas\data\data.csv')
# C:\Users\User\AppData\Local\Temp\ipykernel_25912\1375733126.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('G:\PythonLearningCourse\Pandas\data\data.csv')
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Read from a CSV file
# ----> 2 df = pd.read_csv('G:\PythonLearningCourse\Pandas\data\data.csv')
#       4 # Write to a CSV file
#       5 df.to_csv('output.csv', index=False)
#
# ...
